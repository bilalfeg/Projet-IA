# %%
import json
import pandas as pd

# Charger les données JSON à partir d'un fichier
with open('materials_msi_scores.json', 'r') as file:
    data = json.load(file)

# Extraire les données pertinentes
materials_list = []

for material in data['hits']:
    material_name = material['name']
    material_impact = material['scores']

    materials_list.append({
        'name': material_name,
        'globalWarmingPts': material_impact['globalWarmingPts'],
        'eutrophicationPts': material_impact['eutrophicationPts'],
        'waterScarcityPts': material_impact['waterScarcityPts'],
        'abioticDepletionPts': material_impact['abioticDepletionPts'],
        'chemistryPts': material_impact['chemistryPts'],
        'impact': material_impact['impact'],
        'waterConsumption': material_impact['waterConsumption'],
        'biogenicCarbon': material_impact['biogenicCarbon']
    })

# Créer un DataFrame pandas
df_materials_score_msi = pd.DataFrame(materials_list)

# Exporter les données dans un fichier CSV
df_materials_score_msi.to_csv("higgs_score_materials.csv", index=False)
df_materials_score_msi.head(25)
# Out:
#                                        name  globalWarmingPts
# 0                       Monolithic Laminate          4.518294  \
# 1                     Goose Down Insulation          1.528904
# 2                      Duck Down insulation          1.528904
# 3                                      Iron          2.345487
# 4                                       Tin         20.558422
# 5                                      Wood          1.086127
# 6                                     Paper          0.550030
# 7             Polylactic Acid (PLA) plastic          4.086170
# 8          Polyvinyl chloride (PVC) plastic          4.216693
# 9                  Polypropylene insulation          3.117402
# 10                          Silicone rubber          7.654837
# 11  Thermoplastic polyurethane (TPU) rubber          7.519219
# 12        Ethylene-vinyl acetate (EVA) foam          4.874142
# 13       Thermoplastic elastomer (TPE) Foam          6.723505
# 14                 Polyethylene (PE) Fabric          5.074343
# 15                     Viscose/Rayon fabric         15.867004
# 16          Expanded Polystyrene (EPS) foam          5.134932
# 17                      BiComponent Coating          2.988971
# 18                      Microporous Coating          3.640650
# 19                    Sheep Wool insulation         33.115849
# 20                                     Lead          1.813788
# 21                                     Zinc          2.458186
# 22                                 Aluminum          8.728277
# 23                                 Titanium         31.115766
# 24                                 Chromium          8.525801
#
#     eutrophicationPts  waterScarcityPts  abioticDepletionPts  chemistryPts
# 0            0.958347          0.146292             7.888935      4.872923  \
# 1            3.918803          0.269525             0.754759      6.928230
# 2            3.918803          0.269525             0.754759      6.928230
# 3            0.594290          0.036951             1.912598      4.863257
# 4           59.770568          5.945609            17.582154      5.854645
# 5            0.586921          0.133077             0.907980      3.928481
# 6            0.313460          0.006346             0.513307      0.956938
# 7            4.112577          1.033143             3.655444      5.839471
# 8            1.277651          0.390613             5.482632      5.839471
# 9            0.917713          0.245765             5.964685      2.919887
# 10           2.426876          0.602609             7.173064      5.869819
# 11           2.071754          0.480417            10.448992      5.869819
# 12           1.547847          0.643721             7.525792      6.016463
# 13           2.023062          0.471306             8.827936      6.016463
# 14           2.532491          0.483263             8.388285      6.016427
# 15          12.336557          3.644619            14.015122      9.491143
# 16           1.809663          0.524045             7.549962      6.016463
# 17           0.532015          0.337940             5.635929      2.890145
# 18           0.692453          0.074490             6.838705      2.890145
# 19          11.727781          2.072601             3.592257      1.948583
# 20           0.578233          0.205423             1.432440      3.871868
# 21           0.813355          0.572402             2.196626      3.871868
# 22           2.838425          0.917161             6.030033      4.863257
# 23          85.643975          5.761063            26.097231      4.863257
# 24           2.756670          0.486494             6.192799      3.871868
#
#         impact  waterConsumption  biogenicCarbon
# 0    18.384790         30.981163        0.000000
# 1    13.400220         14.924221        0.894400
# 2    13.400220         14.924221        0.000000
# 3     9.752583          7.202557        0.000000
# 4   109.711399        300.507836        0.000000
# 5     6.642587          7.412420        0.515789
# 6     2.340080          8.707381        0.420000
# 7    18.726806        100.038741        0.515358
# 8    17.207060         25.397099        0.000000
# 9    13.165451         17.121964        0.000000
# 10   23.727205         72.578579        0.000000
# 11   26.390201         32.272370        0.000000
# 12   20.607965         40.014873        0.000000
# 13   24.062271         39.790217        0.000000
# 14   22.494809         30.753940        0.000000
# 15   55.354445        258.310864        0.482066
# 16   21.035065         28.499305        0.000000
# 17   12.385001         22.698981        0.000000
# 18   14.136445         25.413022        0.000000
# 19   52.457071         67.613638        0.518135
# 20    7.901753         20.512793        0.000000
# 21    9.912436         24.484923        0.000000
# 22   23.377152        185.511721        0.000000
# 23  153.481292        291.183826        0.000000
# 24   21.833632         24.702789        0.000000
